# b'Starting training using file /Users/shuhei.shogen/Downloads/text8\n'b'100K\r200K\r300K\r400K\r500K\r600K\r700K\r800K\r900K\r1000K\r1100K\r1200K\r1300K\r1400K\r1500K\r1600K\r1700K\r1800K\r1900K\r2000K\r2100K\r2200K\r2300K\r2400K\r2500K\r2600K\r2700K\r2800K\r2900K\r3000K\r3100K\r3200K\r3300K\r3400K\r3500K\r3600K\r3700K\r3800K\r3900K\r4000K\r4100K\r4200K\r4300K\r4400K\r4500K\r4600K\r4700K\r4800K\r4900K\r5000K\r5100K\r5200K\r5300K\r5400K\r5500K\r5600K\r5700K\r5800K\r5900K\r6000K\r6100K\r6200K\r6300K\r6400K\r6500K\r6600K\r6700K\r6800K\r6900K\r7000K\r7100K\r7200K\r7300K\r7400K\r7500K\r7600K\r7700K\r7800K\r7900K\r8000K\r8100K\r8200K\r8300K\r8400K\r8500K\r8600K\r8700K\r8800K\r8900K\r9000K\r9100K\r9200K\r9300K\r9400K\r9500K\r9600K\r9700K\r9800K\r9900K\r10000K\r10100K\r10200K\r10300K\r10400K\r10500K\r10600K\r10700K\r10800K\r10900K\r11000K\r11100K\r11200K\r11300K\r11400K\r11500K\r11600K\r11700K\r11800K\r11900K\r12000K\r12100K\r12200K\r12300K\r12400K\r12500K\r12600K\r12700K\r12800K\r12900K\r13
# ...

# %%
model = word2vec.load('/Users/shuhei.shogen/Downloads/text8.bin')

# %%
model.vocab
# Out:
# array(['</s>', 'the', 'of', ..., 'dakotas', 'nias', 'burlesques'],
#       dtype='<U78')

# %%
model.vectors.shape
# Out:
# (98331, 100)

# %%
model.vectors
# Out:
# array([[ 0.14333282,  0.15825513, -0.13715845, ...,  0.05456942,
#          0.10955409,  0.00693387],
#        [ 0.04222504,  0.14841424, -0.15832897, ...,  0.03415966,
#         -0.10728977, -0.07866685],
#        [ 0.24012774,  0.11773524,  0.00415283, ...,  0.01371265,
#          0.00412277,  0.06481728],
#        ...,
#        [-0.09399424,  0.10001848,  0.02479052, ...,  0.11605066,
#         -0.07554167, -0.00772643],
#        [-0.00635316,  0.0293138 ,  0.09682925, ..., -0.01857024,
#         -0.18716888, -0.05031466],
#        [-0.04441606, -0.01849867,  0.01590944, ...,  0.04656721,
#         -0.16180718, -0.04336931]])

# %%
model['dog'].shape
# Out:
# (100,)

# %%
model['dog'][:10]
# Out:
# array([ 0.03464004,  0.18925463, -0.01302341,  0.11133592,  0.1124661 ,
#         0.03214702, -0.0822289 ,  0.11930333,  0.04322115, -0.06411406])

# %%
indexes, metrics = model.cosine('socks')
indexes, metrics
# Out:
# (array([28915, 30711, 20002, 23705, 33874, 14631, 24195, 26323, 22914, 22992]),
#  array([ 0.84805387,  0.83571117,  0.82938359,  0.82891537,  0.82855269,
#          0.82805987,  0.82535568,  0.82183522,  0.81873553,  0.81828325]))

# %%
model.vocab[indexes]
# Out:
# array(['pumpkin', 'gravy', 'hairy', 'striped', 'nosed', 'winged', 'petals',
#        'haired', 'skirt', 'bock'],
#       dtype='<U78')

# %%
model.generate_response(indexes, metrics)
# Out:
# rec.array([('pumpkin', 0.8480538706531564), ('gravy', 0.8357111743111493),
#  ('hairy', 0.8293835917458129), ('striped', 0.8289153744110109),
#  ('nosed', 0.828552688731497), ('winged', 0.8280598687864906),
#  ('petals', 0.8253556775318553), ('haired', 0.8218352153890405),
#  ('skirt', 0.818735529811425), ('bock', 0.8182832487852302)],
#           dtype=[('word', '<U78'), ('metric', '<f8')])

# %%
model.generate_response(indexes, metrics).tolist()
# Out:
# [('pumpkin', 0.8480538706531564),
#  ('gravy', 0.8357111743111493),
#  ('hairy', 0.8293835917458129),
#  ('striped', 0.8289153744110109),
#  ('nosed', 0.828552688731497),
#  ('winged', 0.8280598687864906),
#  ('petals', 0.8253556775318553),
#  ('haired', 0.8218352153890405),
#  ('skirt', 0.818735529811425),
#  ('bock', 0.8182832487852302)]

# %%
indexes, metrics = model.cosine('los_angeles')
model.generate_response(indexes, metrics).tolist()
# Out:
# [('san_francisco', 0.8920394829123179),
#  ('san_diego', 0.8707364900049557),
#  ('seattle', 0.8456968173633479),
#  ('las_vegas', 0.8364297515808231),
#  ('chicago', 0.8321413430647392),
#  ('miami', 0.831835917171307),
#  ('california', 0.827599497187704),
#  ('atlanta', 0.8188639767040207),
#  ('detroit', 0.8186988738874126),
#  ('cleveland', 0.8176843710457244)]

# %%
indexes, metrics = model.analogy(pos=['king', 'woman'], neg=['man'], n=10)
indexes, metrics
# Out:
# (array([1087, 7523, 1145,  648, 1335,  344, 8419, 6768, 1006, 1826]),
#  array([ 0.28512914,  0.2719392 ,  0.27080555,  0.26520277,  0.26427404,
#          0.26227219,  0.26086162,  0.25982716,  0.25754776,  0.25589516]))

# %%
model.generate_response(indexes, metrics).tolist()
# Out:
# [('queen', 0.2851291391896258),
#  ('empress', 0.27193919808610373),
#  ('prince', 0.2708055470360281),
#  ('emperor', 0.2652027722530966),
#  ('wife', 0.26427404023223217),
#  ('son', 0.26227218529810786),
#  ('aragon', 0.2608616217236767),
#  ('regent', 0.25982715534062195),
#  ('daughter', 0.25754776413160013),
#  ('throne', 0.2558951600114827)]

# %%
clusters = word2vec.load_clusters('/Users/shuhei.shogen/Downloads/text8-clusters.txt')

# %%
clusters['dogs']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-fb9f9b5d2740> in <module>()
# ----> 1 clusters['dogs']
#
# /Users/shuhei.shogen/.pyenv/versions/3.5.2/lib/python3.5/site-packages/word2vec/wordclusters.py in __getitem__(self, word)
#      21
#      22     def __getitem__(self, word):
# ---> 23         return self.get_cluster(word)
#      24
#      25     def get_cluster(self, word):
#
# /Users/shuhei.shogen/.pyenv/versions/3.5.2/lib/python3.5/site-packages/word2vec/wordclusters.py in get_cluster(self, word)
#      27         Returns the cluster number for a word in the vocabulary
#      28         """
# ---> 29         idx = self.ix(word)
#      30         return self.clusters[idx]
#      31
#
# /Users/shuhei.shogen/.pyenv/versions/3.5.2/lib/python3.5/site-packages/word2vec/wordclusters.py in ix(self, word)
# ...
